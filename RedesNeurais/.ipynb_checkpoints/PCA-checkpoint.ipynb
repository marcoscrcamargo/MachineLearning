# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib notebook
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale

# %%
iris = pd.read_csv('../data/iris.data', names=['sepal length', 'sepal width', 'petal length', 'petal width', 'class'])
iris.head()
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris_std = iris.copy()
iris_std[iris.columns[0:4]] = iris[iris.columns[0:4]] - iris[iris.columns[0:4]].mean()/iris[iris.columns[0:4]].std()
iris_std.head()
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0     -1.956602     -3.54345     -0.730256    -1.370661  Iris-setosa
# 1     -2.156602     -4.04345     -0.730256    -1.370661  Iris-setosa
# 2     -2.356602     -3.84345     -0.830256    -1.370661  Iris-setosa
# 3     -2.456602     -3.94345     -0.630256    -1.370661  Iris-setosa
# 4     -2.056602     -3.44345     -0.730256    -1.370661  Iris-setosa

# %%
for i in range(len(iris_std.columns[:-1])):
    plt.subplot(2, 2, i+1)
    col = iris_std.columns[i]
    plt.title(col)
    for c in iris_std['class'].unique():
        iris_std[iris_std['class'] == c][col].plot.hist(alpha=0.3)
plt.legend(iris_std['class'].unique())
        
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="867">

# %%
iris_std.boxplot(by='class')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="901">

# %%
sns.pairplot(data=iris_std, hue='class')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="948">

# %%
corr = iris_std.corr()
sns.heatmap(corr)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="755">

# %%
# cov = iris_std.cov()
# Calculando autovalores e autovetores
va, ve = np.linalg.eig(corr)
# va, ve = np.linalg.eig(cov)
# Ordenando autovalores e autovetores
sort_idx = np.argsort(va)[::-1]
einvals = va[sort_idx]
einvecs = ve[sort_idx]
# plt.plot(np.cumsum(einvals), '-o')
# plt.show()

# %%
EVR = einvals/einvals.sum()
pd.DataFrame(EVR.reshape((1,4)), columns=iris_std.columns[sort_idx])
# Out:
#    sepal length  sepal width  petal length  petal width
# 0      0.727705     0.230305      0.036838     0.005152

# %%
einvecs[:,:3]
# Out:
# array([[ 0.52237162, -0.37231836, -0.72101681],
#        [-0.26335492, -0.92555649,  0.24203288],
#        [ 0.58125401, -0.02109478,  0.14089226],
#        [ 0.56561105, -0.06541577,  0.6338014 ]])

# %%
iris_pca = iris_std.copy()
x = iris_pca[iris_pca.columns[:-1]].values
# x = x - x.mean()
# x = np.dot(x[:, sort_idx], einvecs)
# x = x/np.sqrt(va)
iris_pca[iris_pca.columns.take(sort_idx)] = x @ einvecs
# sns.pairplot(iris_pca, hue='class')
# plt.show()
iris_pca.head()
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0     -1.288613     4.113210     -0.418502    -0.205313  Iris-setosa
# 1     -1.261410     4.650452     -0.395316    -0.195644  Iris-setosa
# 2     -1.476681     4.541914     -0.216795    -0.192755  Iris-setosa
# 3     -1.386332     4.667482     -0.140718    -0.366772  Iris-setosa
# 4     -1.367186     4.057886     -0.322197    -0.243926  Iris-setosa

# %%
columns = iris.columns
x = iris_std[columns[:-1]]

# x = scale(x)

pca = PCA(n_components = 3)
x = pca.fit_transform(x)
x[0,:]
# Out:
# array([-2.68420713,  0.32660731, -0.02151184])

# %%
from mpl_toolkits.mplot3d import Axes3D

np.random.seed(5)

centers = [[1, 1], [-1, -1], [1, -1]]
X = iris[iris.columns[:-1]].values
y = iris[iris.columns[-1]].copy()
for i in range(y.unique().size):
    y[y == y.unique()[i]] = i
y = y.values.astype(int)

fig = plt.figure(1, figsize=(4, 3))
plt.clf()
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)

plt.cla()

for name, label in [('Setosa', 0), ('Versicolour', 1), ('Virginica', 2)]:
    ax.text3D(X[y == label, 0].mean(),
              X[y == label, 1].mean() + 1.5,
              X[y == label, 2].mean(), name,
              horizontalalignment='center',
              bbox=dict(alpha=.5, edgecolor='w', facecolor='w'))
# Reorder the labels to have colors matching the cluster results
y = np.choose(y, [1, 2, 0]).astype(np.float)
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=y, cmap=plt.cm.nipy_spectral,
           edgecolor='k')

ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="775">

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


from sklearn import decomposition

np.random.seed(5)

centers = [[1, 1], [-1, -1], [1, -1]]

X = iris[iris.columns[:-1]].values
y = iris[iris.columns[-1]].copy()
for i in range(y.unique().size):
    y[y == y.unique()[i]] = i
y = y.values.astype(int)

fig = plt.figure(1, figsize=(4, 3))
plt.clf()
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)

plt.cla()
pca = decomposition.PCA(n_components=4)
pca.fit(X)
X = pca.transform(X)

for name, label in [('Setosa', 0), ('Versicolour', 1), ('Virginica', 2)]:
    ax.text3D(X[y == label, 0].mean(),
              X[y == label, 1].mean() + 1.5,
              X[y == label, 2].mean(), name,
              horizontalalignment='center',
              bbox=dict(alpha=.5, edgecolor='w', facecolor='w'))
# Reorder the labels to have colors matching the cluster results
y = np.choose(y, [1, 2, 0]).astype(np.float)
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=y, cmap=plt.cm.nipy_spectral,
           edgecolor='k')

ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="651">
